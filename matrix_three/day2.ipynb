# %% [markdown]
# ## Data visualization

# %%
# !pwd
# Out:
# /content

# %%
# %cd "drive/My Drive/Colab Notebooks/data_workshop/matrix_three"
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop/matrix_three

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop/matrix_three

# %%
ls
# Out:
# data/  day1.ipynb  day2.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
ls data
# Out:
# signnames.csv  test.p  train.p

# %%
train = pd.read_pickle('data/train.p')
train.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
X_train, y_train = train['features'], train['labels']

# %%
X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %% [markdown]
# Images are in RGB format. Each photo contain 3 levels. Hence each photo consists of 32x32x3 numbers.

# %%
plt.imshow(X_train[0]);

# %%
X_train[0]
# Out:
# array([[[28, 25, 24],
#         [27, 24, 23],
#         [27, 24, 22],
#         ...,
#         [32, 28, 24],
#         [31, 27, 25],
#         [31, 27, 26]],
#
#        [[29, 26, 25],
#         [27, 25, 23],
#         [27, 25, 23],
#         ...,
#         [32, 28, 24],
#         [31, 27, 24],
#         [30, 27, 25]],
#
#        [[28, 26, 26],
#         [27, 25, 23],
#         [26, 25, 23],
#         ...,
#         [32, 28, 24],
#         [31, 27, 24],
#         [30, 27, 25]],
#
#        ...,
#
#        [[27, 24, 23],
#         [28, 25, 24],
#         [30, 25, 24],
#         ...,
#         [27, 24, 23],
#         [28, 24, 22],
#         [29, 25, 22]],
#
#        [[28, 23, 23],
#         [29, 24, 24],
#         [31, 25, 24],
#         ...,
#         [27, 24, 23],
#         [28, 24, 22],
#         [28, 24, 21]],
#
#        [[29, 23, 23],
#         [30, 24, 24],
#         [32, 24, 23],
#         ...,
#         [27, 24, 22],
#         [27, 23, 21],
#         [26, 22, 20]]], dtype=uint8)

# %%
signs = pd.read_csv('data/signnames.csv')
signs.head()
# Out:
#    a                     b
# 0  0  Speed limit (20km/h)
# 1  1  Speed limit (30km/h)
# 2  2  Speed limit (50km/h)
# 3  3  Speed limit (60km/h)
# 4  4  Speed limit (70km/h)

# %%
dict_signs = signs.to_dict()['b']

# %%
dict_signs
# Out:
# {0: 'Speed limit (20km/h)',
#  1: 'Speed limit (30km/h)',
#  2: 'Speed limit (50km/h)',
#  3: 'Speed limit (60km/h)',
#  4: 'Speed limit (70km/h)',
#  5: 'Speed limit (80km/h)',
#  6: 'End of speed limit (80km/h)',
#  7: 'Speed limit (100km/h)',
#  8: 'Speed limit (120km/h)',
#  9: 'No passing',
#  10: 'No passing for vehicles over 3.5 metric tons',
#  11: 'Right-of-way at the next intersection',
#  12: 'Priority road',
#  13: 'Yield',
#  14: 'Stop',
#  15: 'No vehicles',
#  16: 'Vehicles over 3.5 metric tons prohibited',
#  17: 'No entry',
#  18: 'General caution',
#  19: 'Dangerous curve to the left',
#  20: 'Dangerous curve to the right',
#  21: 'Double curve',
#  22: 'Bumpy road',
#  23: 'Slippery road',
#  24: 'Road narrows on the right',
#  25: 'Road work',
#  26: 'Traffic signals',
#  27: 'Pedestrians',
#  28: 'Children crossing',
#  29: 'Bicycles crossing',
#  30: 'Beware of ice/snow',
#  31: 'Wild animals crossing',
#  32: 'End of all speed and passing limits',
#  33: 'Turn right ahead',
#  34: 'Turn left ahead',
#  35: 'Ahead only',
#  36: 'Go straight or right',
#  37: 'Go straight or left',
#  38: 'Keep right',
#  39: 'Keep left',
#  40: 'Roundabout mandatory',
#  41: 'End of no passing',
#  42: 'End of no passing by vehicles over 3.5 metric tons'}

# %%
X_train[ y_train == 20 ].shape
# Out:
# (300, 32, 32, 3)

# %%
for id_sign in dict_signs.keys():
    given_signs = X_train[y_train == id_sign]

    plt.figure(figsize=(15,5))
    for i in range(9):
        plt.subplot('19{0}'.format(i+1))
        plt.imshow(given_signs[i])
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cnt = Counter(y_train).most_common()

id_labels, cnt_labels = zip(*cnt)
ids = range(len(id_labels))

plt.figure(figsize=(20,5))
plt.bar(ids, cnt_labels);
plt.xlabel('Znaki')
labels = [dict_signs[id_labels[id]] for id in id_labels]
plt.xticks(ids, labels, rotation='vertical')
plt.title('Znaki drogowe - liczba wystąpień');

#plt.xaxis()

# %%
# !git add ./

# %%
# !git config --global user.email 'kmwolowiec@gmail.com'
# !git config --global user.name 'Krzysiek'

# %%
# !git commit -m "Day 2 added"
# Out:
# [master 26085a5] Day 2 added
#  2 files changed, 2 insertions(+)
#  create mode 100644 matrix_three/day1.ipynb
#  create mode 100644 matrix_three/day2.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 63.89 KiB | 5.81 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/kmwolowiec/data_workshop.git
# To https://github.com/ThePearsSon/data_workshop.git
#    38b5684..26085a5  master -> master
